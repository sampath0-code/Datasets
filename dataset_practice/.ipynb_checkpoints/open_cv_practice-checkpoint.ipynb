# %%
import matplotlib.pylab as plt

# %%
! pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\sampath\anaconda3\lib\site-packages (4.5.4.58)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\sampath\anaconda3\lib\site-packages (from opencv-python) (1.20.2)

# %%
import cv2

# %%
img = cv2.imread('lena.jpg')

# %%
img
# Out:
# array([[[128, 138, 225],
#         [127, 137, 224],
#         [126, 136, 224],
#         ...,
#         [126, 145, 236],
#         [110, 129, 220],
#         [ 86, 104, 197]],
#
#        [[127, 137, 224],
#         [127, 137, 224],
#         [127, 137, 224],
#         ...,
#         [130, 150, 235],
#         [112, 132, 217],
#         [ 83, 102, 189]],
#
#        [[127, 137, 224],
#         [127, 137, 224],
#         [128, 138, 225],
#         ...,
#         [127, 148, 230],
#         [112, 133, 215],
#         [ 85, 105, 190]],
#
#        ...,
#
#        [[ 55,  21,  82],
#         [ 54,  20,  81],
#         [ 62,  28,  92],
#         ...,
#         [ 82,  71, 175],
#         [ 78,  68, 175],
#         [ 74,  65, 175]],
#
#        [[ 55,  18,  80],
#         [ 56,  19,  81],
#         [ 66,  32,  96],
#         ...,
#         [ 82,  69, 177],
#         [ 80,  71, 181],
#         [ 81,  72, 183]],
#
#        [[ 56,  19,  81],
#         [ 58,  21,  83],
#         [ 68,  34,  98],
#         ...,
#         [ 81,  68, 176],
#         [ 81,  72, 183],
#         [ 84,  74, 188]]], dtype=uint8)

# %%
plt.imshow(img)
plt.title('Lena')
plt.axis('on')
plt.show()

# %%
cap = cv2.VideoCapture(0);
while (True):
    ret, frame = cap.read()
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('frame', gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break  
cap.release()
cv2.destroyAllWindows()
